# %%
from FullAnalysis import *
from SimultaneousParameterEstimation import SimultaneousParameterEstimation

# %% [markdown]
# The **information*importariable encodes the reaction being modelled, and the **FullAnalysisRun** will print:
# - A full simulation, plotting a table with; all the molecular species, their initial concentrations, and the final concentrations.
# - A table of the rate values used/
# - All the ODE's of the system
# - The sensitivity and normalised sensitivity Heatmaps
# - The rate parameter estimation
#
# The variable **information** is a list of lists. Where each list describes the variable, its production process, and its miRNA regulation.
#
# **Examples:**
#
# - So for a simulation of RFP production and GFP production:  [ [ "R" , "full" , " " ] ,   [ "G" , "full" , " " ] ]
#
# - For a simulation of RFP production, GFP production and 3' miRNA production: [ [ "R" , "full" , " " ] ,   [ "G" , "full" , " " ],   [ "3" , "mRNA" , " " ] ]
#
# - For a simulation of RFP production, GFP production and 3' miRNA production. Whereby RFP is being regulated by 3' miRNA with 1 binding site:  [ [ "R" , "full" , "1TS 3" ] ,   [ "G" , "full" , " " ],   [ "3" , "mRNA" , " " ] ]
#
# - For a simulation of RFP production, GFP production and 5' miRNA production. Whereby RFP is being regulated by 5' miRNA with 3 binding sites: [ [ "R" , "full" , "3TS 5" ] ,   [ "G" , "full" , " " ],   [ "5" , "mRNA" , " " ] ]

# %%
information = [ [ "R" , "full" , "" ] , [ "G" , "full" , " " ], [ "N" , "full" , " " ] ]
information_label = "Control"
FullAnalysisRun(information, information_label)
# Out:
# ---------------------------------------------------------
# |    Species 	|    Initial values 	|  Final values	|
# ---------------------------------------------------------
# | Pol 		| 10000.0 		| 7960.512 	|
# | Rib 		| 10000.0 		| 0.045 	|
# | Exo 		| 100.0 		| 0.087 	|
# | D_R 		| 10.0 			| 0.003 	|
# | Cd_R 		| 0.0 			| 9.997 	|
# | Nd_R 		| 0.0 			| 9.997 	|
# | m_R 		| 0.0 			| 2198.494 	|
# | Cm_R 		| 0.0 			| 48.987 	|
# | Nm_R 		| 0.0 			| 48.775 	|
# | Ym_R 		| 0.0 			| 0.958 	|
# | YC_R 		| 0.0 			| 0.021 	|
# | P_R 		| 0.0 			| 19508.128 	|
# | D_G 		| 10.0 			| 0.003 	|
# | Cd_G 		| 0.0 			| 9.997 	|
# | Nd_G 		| 0.0 			| 9.997 	|
# | m_G 		| 0.0 			| 2198.494 	|
# | Cm_G 		| 0.0 			| 48.987 	|
# | Nm_G 		| 0.0 			| 48.775 	|
# | Ym_G 		| 0.0 			| 0.958 	|
# | YC_G 		| 0.0 			| 0.021 	|
# | P_G 		| 0.0 			| 19508.128 	|
# | D_N 		| 1000.0 		| 0.251 	|
# | Cd_N 		| 0.0 			| 999.749 	|
# | Nd_N 		| 0.0 			| 999.749 	|
# | m_N 		| 0.0 			| 219849.374 	|
# | Cm_N 		| 0.0 			| 4898.746 	|
# | Nm_N 		| 0.0 			| 4877.487 	|
# | Ym_N 		| 0.0 			| 95.819 	|
# | YC_N 		| 0.0 			| 2.135 	|
# | P_N 		| 0.0 			| 1950812.79 	|
# ---------------------------------------------------------
# |     Rates	|  Rate values	|
# ---------------------------------
# | km_p 		| 0.1 		|
# | km_m 		| 0.1 		|
# | km 		| 0.1 		|
# | km_c 		| 0.1 		|
# | kd_p 		| 0.1 		|
# | kd_m 		| 0.1 		|
# | kd 		| 0.1 		|
# | kd_c 		| 0.1 		|
# | kX_m 		| 0.005 	|
# | kdeg 		| 1 		|
# | lam_P 	| 0.00025 	|
# ---------------------------------
# d/dt( Pol ) =  Cd_G*kd_m + Cd_N*kd_m + Cd_R*kd_m - D_G*Pol*kd_p - D_N*Pol*kd_p - D_R*Pol*kd_p + Nd_G*kd_c + Nd_N*kd_c + Nd_R*kd_c
# d/dt( Rib ) =  Cm_G*km_m + Cm_N*km_m + Cm_R*km_m + Nm_G*Ym_G*kdeg/(Cm_G + m_G + 1.0e-50) + Nm_G*km_c + Nm_N*Ym_N*kdeg/(Cm_N + m_N + 1.0e-50) + Nm_N*km_c + Nm_R*Ym_R*kdeg/(Cm_R + m_R + 1.0e-50) + Nm_R*km_c - Rib*km_p*m_G - Rib*km_p*m_N - Rib*km_p*m_R + YC_G*kdeg*(Nm_G/(Cm_G + m_G + 1.0e-50) + 1) + YC_N*kdeg*(Nm_N/(Cm_N + m_N + 1.0e-50) + 1) + YC_R*kdeg*(Nm_R/(Cm_R + m_R + 1.0e-50) + 1)
# d/dt( Exo ) =  -Cm_G*Exo*kX_m - Cm_N*Exo*kX_m - Cm_R*Exo*kX_m - Exo*kX_m*m_G - Exo*kX_m*m_N - Exo*kX_m*m_R + YC_G*kdeg + YC_N*kdeg + YC_R*kdeg + Ym_G*kdeg + Ym_N*kdeg + Ym_R*kdeg
# d/dt( D_R ) =  Cd_R*kd + Cd_R*kd_m - D_R*Pol*kd_p
# d/dt( Cd_R ) =  -Cd_R*kd - Cd_R*kd_m + D_R*Pol*kd_p
# d/dt( Nd_R ) =  Cd_R*kd - Nd_R*kd_c
# d/dt( m_R ) =  Cm_R*km + Cm_R*km_m - Exo*kX_m*m_R + Nd_R*kd_c - Rib*km_p*m_R
# d/dt( Cm_R ) =  -Cm_R*Exo*kX_m - Cm_R*km - Cm_R*km_m + Rib*km_p*m_R
# d/dt( Nm_R ) =  -Cm_R*Exo*Nm_R*kX_m/(Cm_R + m_R + 1.0e-50) + Cm_R*km - Exo*Nm_R*kX_m*m_R/(Cm_R + m_R + 1.0e-50) - Nm_R*km_c
# d/dt( Ym_R ) =  Exo*kX_m*m_R - Ym_R*kdeg
# d/dt( YC_R ) =  Cm_R*Exo*kX_m - YC_R*kdeg
# d/dt( P_R ) =  Nm_R*km_c - P_R*lam_P
# d/dt( D_G ) =  Cd_G*kd + Cd_G*kd_m - D_G*Pol*kd_p
# d/dt( Cd_G ) =  -Cd_G*kd - Cd_G*kd_m + D_G*Pol*kd_p
# d/dt( Nd_G ) =  Cd_G*kd - Nd_G*kd_c
# d/dt( m_G ) =  Cm_G*km + Cm_G*km_m - Exo*kX_m*m_G + Nd_G*kd_c - Rib*km_p*m_G
# d/dt( Cm_G ) =  -Cm_G*Exo*kX_m - Cm_G*km - Cm_G*km_m + Rib*km_p*m_G
# d/dt( Nm_G ) =  -Cm_G*Exo*Nm_G*kX_m/(Cm_G + m_G + 1.0e-50) + Cm_G*km - Exo*Nm_G*kX_m*m_G/(Cm_G + m_G + 1.0e-50) - Nm_G*km_c
# d/dt( Ym_G ) =  Exo*kX_m*m_G - Ym_G*kdeg
# d/dt( YC_G ) =  Cm_G*Exo*kX_m - YC_G*kdeg
# d/dt( P_G ) =  Nm_G*km_c - P_G*lam_P
# d/dt( D_N ) =  Cd_N*kd + Cd_N*kd_m - D_N*Pol*kd_p
# d/dt( Cd_N ) =  -Cd_N*kd - Cd_N*kd_m + D_N*Pol*kd_p
# d/dt( Nd_N ) =  Cd_N*kd - Nd_N*kd_c
# d/dt( m_N ) =  Cm_N*km + Cm_N*km_m - Exo*kX_m*m_N + Nd_N*kd_c - Rib*km_p*m_N
# d/dt( Cm_N ) =  -Cm_N*Exo*kX_m - Cm_N*km - Cm_N*km_m + Rib*km_p*m_N
# d/dt( Nm_N ) =  -Cm_N*Exo*Nm_N*kX_m/(Cm_N + m_N + 1.0e-50) + Cm_N*km - Exo*Nm_N*kX_m*m_N/(Cm_N + m_N + 1.0e-50) - Nm_N*km_c
# d/dt( Ym_N ) =  Exo*kX_m*m_N - Ym_N*kdeg
# d/dt( YC_N ) =  Cm_N*Exo*kX_m - YC_N*kdeg
# d/dt( P_N ) =  Nm_N*km_c - P_N*lam_P
# Sentivities calculated for:
# 1  of  11 rates
# 2  of  11 rates
# 3  of  11 rates
# 4  of  11 rates
# 5  of  11 rates
# 6  of  11 rates
# 7  of  11 rates
# 8  of  11 rates
# 9  of  11 rates
# 10  of  11 rates
# 11  of  11 rates
# -----------------------------------------------------------------
# |      Rates	|     Initial Values	|   Estimated Values	|
# -----------------------------------------------------------------
# | km_p 		| 0.1 			| 0.1 			|
# | km_m 		| 0.1 			| 0.1 			|
# | km 		| 0.1 			| 0.1 			|
# | km_c 		| 0.1 			| 0.1 			|
# | kd_p 		| 0.1 			| 0.1 			|
# | kd_m 		| 0.1 			| 0.1 			|
# | kd 		| 0.1 			| 0.1 			|
# | kd_c 		| 0.1 			| 0.1 			|
# | kX_m 		| 0.005 		| 0.005 		|
# | kdeg 		| 1 			| 1.0 			|
# | lam_P 	| 0.00025 		| 0.00025 		|
# -----------------------------------------------------------------

# %%
information_lists = [[["G", "full", ""], ["R", "full", ""], ["N", "full", ""]],      [["G", "full", ""], ["R", "full", "1TS 3"], ["N", "full", ""], ["3", "mRNA", ""]],         [["G", "full", ""], ["R", "full", "1TS 5"], ["N", "full", ""], ["5","mRNA",""]]]
information_lists_labels = ["Control", "1TS3", "1TS5"]
SimultaneousParameterEstimation(information_lists, information_lists_labels)
